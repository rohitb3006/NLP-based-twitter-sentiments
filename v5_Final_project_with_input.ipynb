# %% [markdown]
# Libraries installation

# %% [markdown]
# Importing the libraries

# %%
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd
import seaborn as sns
import numpy as np
from collections import Counter
import tweepy as tw
import datetime
from tweepy import api
import nltk 
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('omw-1.4')
from nltk.stem import PorterStemmer
import nltk
nltk.download('punkt')
# %matplotlib inline
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from textblob import TextBlob
nltk.download('wordnet')
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.naive_bayes import MultinomialNB, BernoulliNB 
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from yellowbrick.classifier import PrecisionRecallCurve
import tweepy
from tweepy.auth import OAuthHandler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from nltk.tokenize import TweetTokenizer
import warnings
warnings.filterwarnings("ignore")
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
from gensim import corpora, models
from scipy.linalg.decomp_svd import null_space
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
def inputacco():
  input_string = input("Enter accounts separated by comma ")
  search_query = input_string.split(",")
  return search_query

# %%
def input_date():
  date_entry = input('Enter a date in YYYY-MM-DD format')
  year, month, day = map(int, date_entry.split('-'))
  date1 = datetime.date(year, month, day)
  return date1

# %%
def notweets():
  no_of_tweeets= int(input("how many tweets u want  "))
  return no_of_tweeets

# %%
def Gettweets(search_query,date1,no_of_tweeets):  
  my_api_key = "OamGj76eUVRKmEE6yndJ7ph6o"
  my_api_secret = "BML9uzcPamD7pOS4fcZymnYS9rFwMfu1KZW9iIXzaD7cpSdSTs"

  # authenticate
  auth = tw.OAuthHandler(my_api_key, my_api_secret)
  api = tw.API(auth, wait_on_rate_limit=True)

  global tweets_copy 
  tweets_copy = []
  for  i in range(0,len(search_query)):
    tweets = tw.Cursor(api.search,
                q=search_query[i],
                lang="en",
                since=date1).items(no_of_tweeets)
    for tweet in tweets:
      tweets_copy.append(tweet)    
  print("Total Tweets fetched:", len(tweets_copy))
  tweets_df= pd.DataFrame() 

# populate the dataframe
  for tweet in tweets_copy:
      hashtags = []
      try:
          for hashtag in tweet.entities["hashtags"]:
              hashtags.append(hashtag["text"])
          text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
      except:
          pass
      tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                                'user_location': tweet.user.location,\
                                                'user_description': tweet.user.description,
                                                'user_verified': tweet.user.verified,
                                                'date': tweet.created_at,
                                                'text': text, 
                                                'original':text,
                                                'hashtags': [hashtags if hashtags else None],
                                                'source': tweet.source}))
      tweets_df = tweets_df.reset_index(drop=True)
      tweets_df.to_csv("data.csv")
  return tweets_df

# %% [markdown]
# Data preprocessing

# %%
def clean(raw):
    """ Remove hyperlinks and markup """
    result = re.sub("<[a][^>]*>(.+?)</[a]>", 'Link.', raw)
    result = re.sub('&gt;', "", result)
    result = re.sub('&#x27;', "'", result)
    result = re.sub('&quot;', '"', result)
    result = re.sub('&#x2F;', ' ', result)
    result = re.sub('<p>', ' ', result)
    result = re.sub('</i>', '', result)
    result = re.sub('&#62;', '', result)
    result = re.sub('<i>', ' ', result)
    result = re.sub("\n", '', result)
    return result

# %%
def remove_username(text):
    Tweet = re.sub(r"user", '', text)
    Tweet = re.sub('@[^\s]+',' ',text)
    #return cleaned_string
    return Tweet

# %%
def remove_num(texts):
   output = re.sub(r'\d+', '', texts)
   return output

# %%
def deEmojify(x):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'', x)

# %%
def unify_whitespaces(x):
    cleaned_string = re.sub(' +', ' ', x)
    return cleaned_string

# %%
def remove_punctuation(text):
    final = "".join(u for u in text if u not in ("?", ".", ";", ":",  "!",'"',','))
    return final

# %%
def remove_symbols(x):
    cleaned_string = re.sub(r"[^a-zA-Z0-9?!.,]+", ' ', x)
    return cleaned_string

# %%
stop=set(stopwords.words("english"))
stemmer=PorterStemmer()
lemma=WordNetLemmatizer()

def remove_stopword(text):
   text=[word.lower() for word in text.split() if word.lower() not in stop]
   return " ".join(text)

# %%
st = stopwords.words('english')
st.append("and")
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = set(string.punctuation)


def clean2(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized

# %%
def Stemming(text):
   stem=[]
   stopword = stopwords.words('english')
   snowball_stemmer = SnowballStemmer('english')
   word_tokens = nltk.word_tokenize(text)
   stemmed_word = [snowball_stemmer.stem(word) for word in word_tokens]
   stem=' '.join(stemmed_word)
   return stem

# %%
def message_cleaning(message):
    test_punc_removed = [char for char in message if char not in string.punctuation]
    test_punc_removed = ''.join(test_punc_removed)
    test_punc_st_removed = []
    for char in test_punc_removed.split():
        if char.lower() not in st:
            test_punc_st_removed.append(char)
    test_punc_st_removed = " ".join(test_punc_st_removed)  
    return test_punc_st_removed

# %%
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# %%
def cleaning(df,review):
    print("****    Cleaning in Process  ***** ")
    time.sleep(5)
    df[review] = df[review].apply(clean2)
    df[review] = df[review].apply(clean)
    df[review] = df[review].apply(deEmojify)
    df[review] = df[review].apply(remove_URL)
    df[review] = df[review].apply(remove_html)
    df[review] = df[review].str.lower()
    df[review] = df[review].apply(remove_num)
    df[review] = df[review].apply(remove_symbols)
    df[review] = df[review].apply(remove_punctuation)
    df[review] = df[review].apply(remove_stopword)
    df[review] = df[review].apply(unify_whitespaces)
    df[review] = df[review].apply(remove_username)
    df[review] = df[review].apply(Stemming)
    df[review] = df[review].apply(message_cleaning)

# %% [markdown]
# **CLassifiying** tweets

# %%
def getsubjectivity(text):
  return TextBlob(text).sentiment.subjectivity
def getpolarity(text):
  return TextBlob(text).sentiment.polarity

# %%
def getanalytics(score):
  if score<0:
    return 'negative'

  elif score==0:    

    return 'neutral' 
  else :
    return 'positive'

# %%
def labelenc(tweets_df):
  label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'.
  tweets_df['label']= label_encoder.fit_transform(tweets_df['analysis'])
  tweets_df['label'].unique()

# %%
def printnegative_tweets(tweets_df):
  j=1
  sortedDF=tweets_df.sort_values(by='Polarity')
  for i in range(0,sortedDF.shape[0]):
    if(sortedDF['analysis'][i]=='negative'):
      print(str(j)+ ') '+sortedDF['original'][i])
      print()
      j=j+1

# %%
def printpositive_tweets(tweets_df):
  j=1
  sortedDF=tweets_df.sort_values(by='Polarity')
  for i in range(0,sortedDF.shape[0]):
    if(sortedDF['analysis'][i]=='positive'):
      print(str(j)+ ') '+sortedDF['original'][i])
      print()
      j=j+1

# %% [markdown]
# Data visualization

# %%
def Polarityandsubjectivityplot(tweets_df):
  plt.figure(figsize=(8,6))
  for i in range(0,tweets_df.shape[0]):
    plt.scatter(tweets_df['Polarity'][i],tweets_df['Subjectivity'][i],color='Blue')

  plt.title('sentiment analysis')
  plt.xlabel('polarity')
  plt.ylabel('subjectiivity')
  plt.show()

# %%
def wordcloudoverall(tweets_df):
  txt = ' '.join(rev for rev in tweets_df.text)
  plt.figure(figsize=(15,8))

  wordcloud = WordCloud(
              background_color = 'black',
              max_font_size = 100,
              max_words = 100,
              width = 1000,
              height = 600
              ).generate(txt)


  plt.imshow(wordcloud,interpolation = 'bilinear')
  plt.axis('off')
  plt.show()

# %%
def wordcloudp(ptweets):
  txt = ' '.join(rev for rev in ptweets)
  plt.figure(figsize=(15,8))

  wordcloud = WordCloud(
              background_color = 'black',
              max_font_size = 100,
              max_words = 100,
              width = 1000,
              height = 600
              ).generate(txt)


  plt.imshow(wordcloud,interpolation = 'bilinear')
  plt.axis('off')
  plt.show()

# %%
def wordcloudn(ntweets):
  txt = ' '.join(rev for rev in ntweets)
  plt.figure(figsize=(15,8))

  wordcloud = WordCloud(
              background_color = 'black',
              max_font_size = 100,
              max_words = 100,
              width = 1000,
              height = 600
              ).generate(txt)


  plt.imshow(wordcloud,interpolation = 'bilinear')
  plt.axis('off')
  plt.show()

# %%
def showgraphnooftweets(tweets_df):
  temp = tweets_df.groupby('label').count()['text'].reset_index().sort_values(by='text',ascending=False)
  temp.style.background_gradient(cmap='Purples')
  print(temp)
  sns.set_theme(style='whitegrid')
  sns.set(rc = {'figure.figsize':(13,8)})
  sns.set_palette("pastel")
  sns.countplot(x='label',data=tweets_df)
  plt.show()

# %%
def histofnumwordtweet(tweets_df):
  df_vis = tweets_df.copy()
  df_vis['Num_word_tweet'] = df_vis['text'].apply(lambda x:len(str(x).split()))
  sns.histplot(data=df_vis, x="Num_word_tweet",bins=30,color='green')
  plt.show()

# %%
def average_word_length(tweets_df):
  fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(10,5))
  word=tweets_df[tweets_df['label']==0]['text'].str.split().apply(lambda x : [len(i) for i in x])
  sns.distplot(word.map(lambda x: np.mean(x)),ax=ax1,color='blue')
  ax1.set_title('Negative Tweets')
  word=tweets_df[tweets_df['label']==1]['text'].str.split().apply(lambda x : [len(i) for i in x])
  sns.distplot(word.map(lambda x: np.mean(x)),ax=ax2,color='red')
  ax2.set_title('Neutral  Tweets')
  word=tweets_df[tweets_df['label']==2]['text'].str.split().apply(lambda x : [len(i) for i in x])
  sns.distplot(word.map(lambda x: np.mean(x)),ax=ax3,color='red')
  ax3.set_title('Positive  Tweets')
  fig.suptitle('Average word length in each tweet')
  plt.show()

# %%
def common_word_count(df_vis):
  df_vis['temp_list'] = df_vis['text'].apply(lambda x:str(x).split())
  top = Counter([item for sublist in df_vis['temp_list'] for item in sublist])
  temp = pd.DataFrame(top.most_common(20))
  temp.columns = ['Common_words','count']
  temp.style.background_gradient(cmap='Blues')
  return temp

# %% [markdown]
# Modeling

# %%
def graphsacc(func,model,X_train_count,X_test_count,y_train,y_test):
  viz = PrecisionRecallCurve(func(),
                            classes=model.classes_,   # label ların isimleri ile gözükmesi için yoksa 0,1,2 gözükür 
                            per_class=True,  # bütün class lar grafikte gözüksün diye True yaptık.
                            cmap="Set1")
  viz.fit(X_train_count,y_train)
  viz.score(X_test_count, y_test)  # test datası üzerinden skorları alıyoruz
  viz.show();

# %%
def all_models(func,diction,X_train_count,X_test_count,y_train,y_test):
  model = func()
  model.fit(X_train_count,y_train)
  model_pred = model.predict(X_test_count)
  model_train_pred = model.predict(X_train_count)
  diction.update({func():accuracy_score(y_test,model_pred) })

  
  
  return  model,model_pred,model_train_pred

# %%
def reports(model_pred,model_train_pred,y_test,y_train):
  print("X Test")
  print(classification_report(y_test,model_pred))
  print("X Train")
  print(classification_report(y_train,model_train_pred))
  plt.figure(figsize=(8,8))
  time.sleep(5)
  sns.heatmap(confusion_matrix(y_test,model_pred),annot = True,fmt = "d")
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  plt.show()

# %% [markdown]
# Part 2 LDA

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
def pr():
  print("\    /\    /  _       _   _         _      ")
  print(" \  /  \  /  |_  |   |   | |  |\/| |_        ")
  print("  \/    \/   |_  |_  |_  |_|  |  | |_       ")
  print()

# %% [markdown]
# main

# %%
import time
from tweepy.auth import OAuthHandler
from sklearn.ensemble import AdaBoostClassifier
 
def main():
  pr() 
  print(" *********************Enter information*************************")
  try:
    search_query  = inputacco()
  except Exception: 
    print("enter again")
    search_query  = inputacco() 
  try:
    date1 = input_date()
  except Exception: 
    print("enter again")
    date1 = input_date()
  try:  
   no_of_tweeets= notweets() 
  except Exception:
    print(" enter again")
    no_of_tweeets= notweets()

  tweets_df=Gettweets(search_query,date1,no_of_tweeets)  
  tweets_df.to_csv("data.csv")
  tweets_df=pd.read_csv("data.csv")
  
  cleaning(tweets_df,'text')
  print("*************Classifying Tweets************** ")
  tweets_df['Subjectivity']=tweets_df['text'].apply(getsubjectivity)
  tweets_df['Polarity']=tweets_df['text'].apply(getpolarity)
  tweets_df["analysis"]=tweets_df['Polarity'].apply(getanalytics)
  labelenc(tweets_df)
  data_text = tweets_df[['original']]
  data_text['index'] = data_text.index
  documents = data_text
  global diction
  diction={}
  global tw
  tw=tweets_df.copy()
  while(True):
    print("***********************************************************")
    print("***********************************************************") 
    print("*** \t1 .....Show Tweets                            ****")
    print("*** \t2 .....Show graphs                            ****")
    print("*** \t3 .....Model creation                         ****")
    print("*** \t4 .....Topic Modelling                        ****")
    print("*** \t5 .....Tweets sentiments using model created  ****")
    print("*** \t6 ..... Exit                                  ****")
    print("***********************************************************")
    print("***********************************************************")
    choice=int(input("Enter a choice      :::: "))
    if choice==1:
    
      print("***********************************************************")
      print("**       1 .  see all Tweets                             **")
      print("**       2 .  see all positive Tweets                    **")
      print("**       3 .  see all negative Tweets                    **")
      print("***********************************************************")
      choice2=int(input("Enter a choice of Tweets :::: "))
      if choice2==1:
        print(tweets_df)
      elif choice2 ==2:
        printpositive_tweets(tweets_df)
        ptweets=tweets_df[tweets_df.analysis == 'positive']
        ptweets=ptweets['original']
        ptweets.to_csv("data_positive.csv")
      elif choice2==3:
        printnegative_tweets(tweets_df)  
        ntweets=tweets_df[tweets_df.analysis == 'negative']
        ntweets=ntweets['original']
        ptweets.to_csv("data_negative.csv")



    elif choice ==2:
      while(True):
        print("__________________________________________________ ")
        print("|                                                 |")
        print("|    1 .  print wordcloud******                   |")
        print("|    2 .  print positive wordlcoud******          |")
        print("|    3 .  print  negative  wordcloud******        |")
        print("|    4 .  print  Subjectivity and polarity******  |")
        print("|    5 .  print  show graph of no tweets ******   |")
        print("|    6 .  print  no of tweets in a word ******    |")
        print("|    7 .  print  average word length              |")
        print("|    8 .  print common words                      |")
        print("|    9 .  Exit                                    |")
        print("|_________________________________________________|")
        print("--------------------------------------------------------")
        choice3=int(input("enter a choice of tweets "))
        if choice3==1:
          wordcloudoverall(tweets_df)
          time.sleep(3)
        elif choice3==2:  
          ptweets=tweets_df[tweets_df.analysis == 'positive']
          ptweets=ptweets['text']
          print(round(ptweets.shape[0]/tweets_df.shape[0]*100,1))
          wordcloudp(ptweets)
          time.sleep(5)
          print("  ")
        elif choice3==3:  
          ntweets=tweets_df[tweets_df.analysis == 'negative']
          ntweets=ntweets['text']
          round(ntweets.shape[0]/tweets_df.shape[0]*100,1)
          wordcloudn(ntweets)
          time.sleep(5)
          print("  ")
        elif choice3==4:
          Polarityandsubjectivityplot(tweets_df)
          time.sleep(5)
        elif choice3==5:
          showgraphnooftweets(tweets_df)
          time.sleep(10)
        elif choice3==6:
          histofnumwordtweet(tweets_df)
          time.sleep(10)
        elif choice3==7:
          average_word_length(tweets_df)
          time.sleep(10)
        elif choice3==8:
          text1=common_word_count(tweets_df)
          text1.style.background_gradient(cmap='Blues')
          return text1
          time.sleep(10)
        else:
          break

    elif choice==3:
      X = tweets_df["text"]
      y = tweets_df["label"]
      X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.30,random_state= 42)
      vt = CountVectorizer(analyzer="word")
      X_train_count = vt.fit_transform(X_train) 
      X_test_count = vt.transform(X_test)
      while(True):
        print("__________________________________________________")
        print("|    1.  Multonmial Naive bayes                  |")
        print("|    2.  SVC                                     |")
        print("|    3.  KNN                                     |")
        print("|    4.  RAndom forest                           |")
        print("|    5.  Aadaboost                               |")
        print("|    6.  show accuracy of all                    |")
        print("|    7.  Boosting of Random forest               |")
        print("|    8.  Boosting of Multinomial naive bayes     |")
        print("|    9.  Exit                                    |")
        print("|________________________________________________|")
        choice4=int(input("enter a choice "))
        print("____________Applying algorithms_____________")
        time.sleep(2)
        if choice4==1:
          time.sleep(5)
          model,model_pred,model_train_pred=all_models(MultinomialNB,diction,X_train_count,X_test_count,y_train,y_test)
          reports(model_pred,model_train_pred,y_test,y_train)
          graphsacc(MultinomialNB,model,X_train_count,X_test_count,y_train,y_test)
          print(diction)
          time.sleep(10)
        elif choice4==2:      
          time.sleep(5)
          model,model_pred,model_train_pred=all_models(SVC,diction,X_train_count,X_test_count,y_train,y_test)
          reports(model_pred,model_train_pred,y_test,y_train)
          graphsacc(SVC,model,X_train_count,X_test_count,y_train,y_test)
          print(diction)
          time.sleep(10)
        elif choice4==3: 
          
          time.sleep(5)
          model,model_pred,model_train_pred=all_models(KNeighborsClassifier,diction,X_train_count,X_test_count,y_train,y_test)
          reports(model_pred,model_train_pred,y_test,y_train)
          graphsacc(KNeighborsClassifier,model,X_train_count,X_test_count,y_train,y_test)
          time.sleep(10)
        elif choice4==4:
          time.sleep(5)
          model,model_pred,model_train_pred=all_models(RandomForestClassifier,diction,X_train_count,X_test_count,y_train,y_test)
          reports(model_pred,model_train_pred,y_test,y_train)
          graphsacc(RandomForestClassifier,model,X_train_count,X_test_count,y_train,y_test)
          time.sleep(10)  
        elif choice4==5:  
          time.sleep(5)
          model,model_pred,model_train_pred=all_models(AdaBoostClassifier,diction,X_train_count,X_test_count,y_train,y_test)
          reports(model_pred,model_train_pred,y_test,y_train)
          graphsacc(AdaBoostClassifier,model,X_train_count,X_test_count,y_train,y_test)
          time.sleep(10)
        elif choice4==6 :
          print(diction)   
        elif choice4==7:
          clf=AdaBoostClassifier(base_estimator=RandomForestClassifier(),n_estimators=100)
          clf.fit(X_train_count,y_train)
          model_pred = clf.predict(X_test_count)
          model_train_pred = clf.predict(X_train_count)
          diction.update({"AdaBoostClassifier(base_estimator=RandomForestClassifier(),n_estimators=100)":accuracy_score(y_test,model_pred) })
          reports(model_pred,model_train_pred,y_test,y_train)

        elif choice4==8:  
          clf=AdaBoostClassifier(base_estimator=MultinomialNB(),n_estimators=100)
          clf.fit(X_train_count,y_train)
          model_pred = clf.predict(X_test_count)
          model_train_pred = clf.predict(X_train_count)
          diction.update({"adabooost Multinomial":accuracy_score(y_test,model_pred) })
          reports(model_pred,model_train_pred,y_test,y_train)
          
        else:
          break
    elif choice==4:
      data_text = tweets_df[['original']]
      data_text['index'] = data_text.index
      documents = data_text
      processed_docs = documents['original'].map(preprocess)
      dictionary = gensim.corpora.Dictionary(processed_docs)
      dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
      bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
      tfidf = models.TfidfModel(bow_corpus)
      corpus_tfidf = tfidf[bow_corpus]
      lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)
      lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
      documents['topic_lda']=null_space
      documents['topic_lda_tf']=null_space
      row_count = len(documents.index) # Return number of rows
      row_count

      for i in range(0,row_count):
        bow_vector = dictionary.doc2bow(preprocess(documents['original'][i]))
        for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
          documents['topic_lda'][i]=lda_model.print_topic(index, 5)
          documents['topic_lda_tf'][i]=lda_model_tfidf.print_topic(index, 5)
          #print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
          break      
      #tweets_df.index = documents.index    
      tweets_df[['Topic modelling LDA', 'Topic modeling lDA Tuning']] = documents[['topic_lda', 'topic_lda_tf']]
      tweets_df.to_csv("topic_modelling.csv")

    elif choice==5:
      print("WARNING: !! Train the model first")
      Keymax = max(zip(diction.values(), diction.keys()))[1]
      print(Keymax) 
      model = Keymax
      model.fit(X_train_count,y_train)
      model_pred = model.predict(X_test_count)
      model_train_pred = model.predict(X_train_count)

      print("the accuracy is ")
      print(accuracy_score(y_test,model_pred))   
      from csv import reader
      print("******************************************")
      sentence=input(" Enter a string")
      print("******************************************")
      global df2
      
      df2=pd.Series(sentence)
     
      X_1 = vt.transform(df2)
      print("*******************OUTPUT**********")
      print( model.predict(X_1))




    else:
      break

# %%
import tweepy
from tweepy.auth import OAuthHandler

main()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# #Delhi #COVID19 #CovidIsNotOver #COVID
#
# 79) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 80) @OfficialDMRC at janak puri west inter change can you allot police please so that commuter can easily come out. Few fellow members rarely allow to take exit easily
#
# 81) @OfficialDMRC @CPCB_OFFICIAL Sir you only send pics when water sprinkles ...just see my video which is just after half an hour ...and the exact suitation of service road ..why DMRC do not take strict action ...we want proper service road . Open the service road asap. 9810240466
# 8810229206
#
# 82) @OfficialDMRC this sticker is getting stick to our clothes pls remove it
# Metro now at Rajouri garden
# Second last coach (A3A31) right hand seats https://t.co/JEUzUOEs16
#
# 83) RT @OfficialDMRC: @CPCB_OFFICIAL @MohdRus320 Hi. Cleaning is being done on daily basis. Service road has already been made by DMRC and main…
#
# 84) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 85) @DivasKu05656899 @OfficialDMRC Who Is not able to write properly, how must be thinking straight...lol
#
# Sir kindly post pics with line and workers not serving else keep it shut
#
# 86) @ansh_singhal @J_a_g_d_e_e_p_ @OfficialDMRC lmao aiims metro station tha😭😭😭
#
# 87) @OfficialDMRC What is the status of Narela metro. Do you know that how poor transportation is there for this area. In every election you are giving lolypop to people. Please update the status.
#
# 88) RT @OfficialDMRC: Normal services have resumed.
#
# 89) RT @flyingspot4518: Our government given right to have water from any hotel or restaurant but we don't have any water point at metro statio…
#
# 90) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 91) @OfficialDMRC @purva_simi @OfficialDMRC Action lo
#
# 92) @OfficialDMRC let me know what's is the price to take new metro card.. And i ahd writeen you a mail i need that answer... If you guys are givinge us a receipt of recharge , u must have the same copy and recording.. U need that.. Copy of that..
#
# 93) @purva_simi @ArvindKejriwal @MetrobusCDMX @msisodia @OfficialDMRC @Transportdepart @dtptraffic @1delhibjp @INCDelhi @DelhiPolice @kgahlot https://t.co/Mr5QMtEtXi
#
# Check full video with public  feedback
#
# 94) @akrai_16 @purva_simi @ArvindKejriwal @MetrobusCDMX @msisodia @OfficialDMRC @Transportdepart @dtptraffic @1delhibjp @INCDelhi @DelhiPolice @kgahlot https://t.co/Mr5QMtEtXi
#
# Full video of this matter
#
# 95) @OfficialDMRC @purva_simi https://t.co/Mr5QMtEtXi
#
# Full video of this matter
#
# 96) @OfficialDMRC @swetasingh2000 Shouldn’t water be free?
#
# 97) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 98) Our government given right to have water from any hotel or restaurant but we don't have any water point at metro station,place where water is essential. @OfficialDMRC @CMODelhi @shipmin_india
#
# 99) @OfficialDMRC I know that it will be refunded but it doesn't mention the time period within which I have to tap the card at an AVM after web top-up. I have already read all the FAQs but it doesn't mention that anywhere. Kindly clarify the time period within which I have to tap my card at AVM.
#
# 100) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 101) @OfficialDMRC
# Raja nahar singh metro station
# First metro timing???
#
# 102) @RoshanRaj08 @OfficialDMRC The video doesn’t show another platform, which is used for Intercity Through Trains (double decker), also run by MTR. That’s one track away from East Rail Line (and has border control measures). With the new platforms, Hung Hom now has a total of 9 platforms.
#
# 103) @RoshanRaj08 @OfficialDMRC terminating*. Right next to the tracks of west rail line, there’s another west rail line track, like side platforms. Both platforms are used alternatively by west rail line. You’ll see this in the video.
#
# 104) @RoshanRaj08 @OfficialDMRC I’ll have to look. It’s anyway the old platforms, not used anymore (since last month). There was a 5th platform near to this which was intercity through trains which went to China, sharing tracks with East Rail Line at times. Let me find a good YouTube video.
#
# 105) @RoshanRaj08 @OfficialDMRC Tuen Ma line terminates at Central, and does this too. Has two platforms for it, island. One train comes, waits a long time, another comes, this leaves later. This is why I wished for Dwarka Grey to be Island, since it isn’t a good interchange anyway. Would’ve helped.
#
# 106) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 107) @RoshanRaj08 @OfficialDMRC A good way to illustrate - that station was like Yamuna Bank, if the Vaishali one was a different line and terminated here, and Noida one was a different line and terminated here too.
#
# 108) @RoshanRaj08 @OfficialDMRC I don’t know if they’ll ever do that tho. They’ve never merged two lines before, but there’s always a first. Hopefully. SKK needs two lines.
#
# 109) @RoshanRaj08 @OfficialDMRC Not a fan of branches, so definitely a good thing it’s dropped.
#
# 110) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 111) @aarnavg17 @OfficialDMRC I think the plan is to have it underground. But elevated platforms will be better for interchange.
#
# 112) @aarnavg17 @OfficialDMRC Atleast the platform should be directly below the existing Red Line one even if it is 2 level below.
#
# 113) @RoshanRaj08 @OfficialDMRC I don’t really think we’ll be having a good interchange at Inderlok anymore though.
#
# 114) @RoshanRaj08 @OfficialDMRC Yep. Space is going to be challenge, the current platform goes long and perpendicular, creating a hurdle. One way would be to create it above the red line platforms, if that’s somehow doable. As long as they do it and not create a new line.
#
# 115) @RoshanRaj08 @OfficialDMRC Then they shifted East Rail Line one level below the new connected Tuen Ma line for a *super important* extension alignment. This extension of 2 stations costed them sharp curves, reducing train’s existing 12 coaches to a maximum of 9.
#
# 116) @RoshanRaj08 @OfficialDMRC Why did Hong Kong do it? They joined two lines into one by creating 4 stations in middle (my Silver-Grey and Brown-Green hope), so had to change direction of the train as it was on level and in between two East Rail Line tracks.
#
# 117) @aarnavg17 @OfficialDMRC Will they gather enough courage to change allignment of existing platforms! Highly doubt it.
# But such a visionary civil project by London Underground way back in 1950s,hats off.
#
# 118) @OfficialDMRC i have lost my metro card at Naraina metro station so i want to my old metro card balance transfer to new card i have metro receipts as last time issued by metro
#
# 119) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 120) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 121) @OfficialDMRC in normal service at blue line today?
#
# 122) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 123) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 124) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 125) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 126) RT @sunilkapoor8: Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking…
#
# 127) @OfficialDMRC The buses are parked in front of the metro station and it says feeder bus. If those buses are authorised to be in metro premises, I'm sure DMRC has something to do with it.
#
# 128) Delhi reports 1118 new #COVID19 cases in last 24 hours.
#
# Hv seen many people in @OfficialDMRC without #Masks. No checking, fine by #delhimetro for people travelling without #Mask. 😷
# @HardeepSPuri @MoHUA_India @RailMinIndia @DMRC_FansClub @teekhi_mircheee https://t.co/t0a2wV3zaf
#
# 129) @Sagar47924861 @OfficialDMRC Ok nice
#
# 130) @OfficialDMRC Kindly take some action
#
# 131) @Namitaangelite @noida_authority @drKabirSardana @vikranttongad @cpsavesoil @PMOIndia @myogiadityanath @CeoNoida @nisharai_ggc @NandiGuptaBJP @Rashmi_dwivedi @swatiagrwlsingh @PJP_2013 @Anjalis09068541 @city_spidey @NGTribunal @ChiefSecyUP @vikramsethi1974 Near Gate no.2 Sector 62 Metro Station. Give breathing space to 3 no. Trees in this area. @OfficialDMRC has " Anarkali" 3 trees here @InduPrakashPCS @CeoNoida @vikranttongad @nisharai_ggc https://t.co/Y3xSde29CS
#
# 132) @OfficialDMRC @mnshkumar356 Cleaning is not properly executed not only in metro stations but also in metro trains, inside lifts, lifts installed entry out locations etc  Paschim Vihar West, Jhilmil and many more stations.  Immediate attention is highly appreciated.
#
# 133) @OfficialDMRC No action is being taken for people without mask in train and station premises. Mask rule must be strictly applied.
#
# 134) RT @KaransinghKjt: Dear @OfficialDMRC, you are requested to take some action on the public coming to eat an drink the station, the way they…
#
# 135) @OfficialDMRC Light of station indication board is not working, at Delhi haat ina. https://t.co/WJLDdjqEYe
#
# 136) are we travelling for free in @OfficialDMRC!! why so much and irrational behaviour at frisking for people using metro services. Don't we have any work to do !! so if they have time..is our time penniless..?@PMOIndia @LtGovDelhi @AAPDelhi @UN_HRC @UNOCHA @UNHumanRights @UNOCHA
#
# 137) @enwhizzlehizzle @ratl0vr @OfficialDMRC ok mam fixing 👩‍🚒👩‍🚒👩‍🚒🦹‍♀️🦹‍♀️🦹‍♀️🦹‍♀️🦹‍♀️
#
# 138) @OfficialDMRC in yellow line at Rajiv chawk station train stand more than 10 mint...we delayed to go destination...pls take action
#
# 139) @OfficialDMRC coach - M1 A28
# Route - Rithala - Dilshad Garden
# Please keep regular check of the coach ,coach was full with leakage of water from AC and passengers were facing trouble https://t.co/HY8fC2Bsje
#
# 140) If Mumbai can, if Kochi Can, if Hyderabad and Pune can, why can't Delhi? It is important to have such facilities to provide first and last mile connectivity to the daily commuters. @OfficialDMRC @DDC_Delhi @PMOIndia @ashishkundra @ArvindKejriwal @LtGovDelhi @narendramodi https://t.co/jbdbsBhX0V
#
# 141) @OfficialDMRC Got refund now... Thankyou for your speedy action @OfficialDMRC
#
# 142) Noida Electronic City Platform No.1 Platform to Track Lock was found in open along with key in the lock, Kindly do the needful @OfficialDMRC https://t.co/kNKRDSxY56
#
# 143) @TheBigGeek @ArvindKejriwal @OfficialDMRC @DelhiPolice On one hand you want women equality and then you want special coaches for women… nice… 👏
#
# 144) While I am no urban-planning professional, I think that higher density housing around public transport (eg @OfficialDMRC's AIIMS station) is better for NCR’s biodiversity than saving trees in the city centre at the cost of sprawling out into our biodiverse hinterlands. n/n
#
# 145) @GaganMakkar9821 @OfficialDMRC @dmrc plz get this coach cleaned as soon as possible. Green line
# Coach no. M5B23 https://t.co/fhNWkUUspF
#
# 146) @OfficialDMRC But is is getting used mostly for crossing road to approach metro station. I think it should be cleaned or maintain properly by some Dept. &amp; Delhi metro also should take the responsibility at some extend.
#
# @DelhiPwd
#
# 147) @dtptraffic @SDMC_Official @ArvindKejriwal @OfficialDMRC Thank you so much.. 🙏🏼
#
# 148) @dtptraffic @SDMC_Official @ArvindKejriwal @OfficialDMRC This is near Chhatarpur Metro Station. Please look into this.. 🙏🏼
#
# 149) @iamkeshary @SDMC_Official @ArvindKejriwal @OfficialDMRC Thanks, kindly mention exact place.
#
# 150) @OfficialDMRC Great
#
# 151) @DrishtiSashakt @OfficialDMRC @ArvindKejriwal @DCP_DelhiMetro @smritiirani @AmitShah @HMOIndia @unwomenindia @UN @UNinIndia @PMOIndia @DeshKeMentor My experience with delhi metro has mostly been pleasant. It just gets uncomfortable at times when men sit in the women's coach since they don't know it's for women.
#
# 152) @OfficialDMRC I'm glad @OfficialDMRC taking commuters feedback seriously and working on it to inhance the entire system.
# Kudos to @OfficialDMRC 👏👏 https://t.co/KNw1t4TDTd
#
# 153) @OfficialDMRC I had recharged online 4 my smart card. I had to go out of station for a while due to which I was not able to validate the recharge at avm. After 10 days I got a msg of refund n some charges were also deducted. I thought I had 30 days to validate? Check the ss. https://t.co/bf7hjzfZiH
#
# 154) @OfficialDMRC could you please give us the exact reason why there is always a station hold of around 10-15 minutes in pink line metro. You guys always say we apologise for your inconvenience, kindly give us the exact reason.
#
# 155) .@OfficialDMRC Kashmiri Gate number 2 machine is not working..
#
# Huge crowd standing ..
#
# Security persons even not checking luggage properly...High Security Threat due to this ...
#
# Plz Note @DCP_DelhiMetro @
#
# 156) @kavita_krishnan @ShreyaDU_AISA @OfficialDMRC @DCP_DelhiMetro "The Messenger of Allah [ﷺ] married me when I was six year’s old, and consummated the marriage with me when I was nine, and I used to play with dolls." - Aisha [RA], in Sunan an-Nasa'i 3378; Vol. 4, Book 26, Hadith 3380.
#
# 157) Dear @OfficialDMRC AC is switched off at Palam metro station platform area right now. Everyone is sweating like hell. People have to go to office or commute for other works. Kindly keep in mind with the current heatwave in ncr region.
#
# 158) But hands down, I was legit fascinated by the network and convenience of @OfficialDMRC. Such a large network with extremely organised and citizen friendly approach through the trains and the best, @OfficialDMRC app. Hats off.
#
# 159) @OfficialDMRC @Abhi___Abhishek Finally a good decision
#
# 160) RT @saviour_era: @OfficialDMRC
# Must ask their free communters to first pay ticket price to travel and then ask for seats.
#
# Tax payers mon…
#
# 161) @OfficialDMRC
# Must ask their free communters to first pay ticket price to travel and then ask for seats.
#
# Tax payers money abused.
# Ticket payers rights abused.
#
# #ShameDelhi https://t.co/45upYjS8gV https://t.co/yd96qqwUNS
#
# 162) Every time I step into a Delhi Metro Station I'm amazed at the quality of infrastructure made and maintained by @delhimetro .Its non-pareil in every sense.
# Proud every time
# @OfficialDMRC https://t.co/33zsToLfV7
#
# 163) @OfficialDMRC Is it advisable to take the metro from New Delhi to HUDA City Centre on a Tuesday morning, with reasonable luggage?
# #DelhiMetro
#
# 164) RT @Manish_AFT: @Bharat06200468 @Riteshyogi459 @OfficialDMRC Exactly bro. For pick pocketing and robbery which is empowered women's main jo…
#
# 165) RT @Manish_AFT: Right to equality ki band bajati hui @OfficialDMRC
#
# They talk about Old people, hypocrites they don't know that YOUNG GIRL…
#
# 166) @aryan_kochhar I agree with you but in recent time I am noticing that @OfficialDMRC is not paying attention on cleaning of stations specifically stairs. Even at Rajiv chowk metro station you would find layer of dirt on stairs &amp; it is also worth to mention that overall cleanliness has plummeted
#
# 167) @aarnavg17 @SelectCITYWALK @OfficialDMRC Similarly I feel for several of the malls at MG Road in Gurgaon. Station is right in the middle of them yet one has to come out in the open and then enter them.
#
# 168) @aarnavg17 @SelectCITYWALK @OfficialDMRC Alignment of that corridor already passes very nearby and since the whole district has not one but multiple of such malls. A direct exit is a no brainer.
#
# 169) @RoshanRaj08 @SelectCITYWALK @OfficialDMRC I frequently go to Logix mall in Noida. It's right opposite metro station. But, once it rained, it absolutelt became a pain, as those roads are not maintained at all. If the concourse wasn't only in middle, there could be a bridge to the mall. https://t.co/Kiqi8d4OCR
#
# 170) @RoshanRaj08 @SelectCITYWALK That's what Hong Kong MTR does. They share some profits from the malls that they have proper exists with. And, yes, currently reaching Select is a pain from metro. Recently only a friend decided not to watch a movie at IMAX because of that lol. Hopefully, let's see. @OfficialDMRC
#
# 171) Dear @OfficialDMRC, you are requested to take some action on the public coming to eat an drink the station, the way they are spreading dirt at the station.🙏#botanicalgardenmetro https://t.co/yzjpVBVhy0
#
# 172) @RoshanRaj08 @OfficialDMRC :')
#
# Best case scenario would've been Airport Express going to Kashmere Gate lmao, as we've to go north, towards Murthal, most prolly. I am definitely not in the mood of getting in the New Delhi station's crowd.
#
# 173) RT @aarnavg17: Might be picking up one friend who starts near Hauz Khas at Rajiv Chowk, and another friend starting at Airport T-3 at Shiva…
#
# 174) @OfficialDMRC White railing missing of right side metro.
#
# 175) @aarnavg17 @OfficialDMRC Yup they do have nice parallel travelators for both directions.
#
# 176) @RoshanRaj08 @OfficialDMRC It has travelators? Nice to know. They need multiple of those at Hauz Khas, given the crowd and distance.
#
# 177) @aarnavg17 Huge missed opportunity here @OfficialDMRC.
#
# 178) Might be picking up one friend who starts near Hauz Khas at Rajiv Chowk, and another friend starting at Airport T-3 at Shivaji Stadium, just because @OfficialDMRC wouldn’t add a new station.
#
# 179) @aryan_kochhar @OfficialDMRC  Lot of it got undone - with delays &amp; snags happening frequently (esp. Blue Line). Feeder bus system for last mile connectivity is not good enough. Traffic outside Metro Stations is a nuisance. Metro still not well integrated with other services. Work in progress ..
#
# 180) @OfficialDMRC Just make sure machine is fill with solution and is working.
# Will check tomorrow morning and will let you know.
# Thank you for replying me.
#
# 181) @OfficialDMRC
# Hi dmrc
# Can you please tell me about the timings of first and last metro of green line
# It would be appreciable if you tell me
#
# 182) Best thing about Aqualine is that its almost vacant all the time. The second one being AC cooling. I appreciate.
# @OfficialUPMetro
# @OfficialDMRC https://t.co/HFY5Uxm3hi
#
# 183) @RoshanRaj08 @OfficialDMRC Okay, so, I took my car out this evening and followed pink line from Anand Vihar to Mayur Vihar Ph-1. Sharing my thoughts below.
#
# 184) @OfficialDMRC Another mismanagement by Noida sector 16 metro staff. Due to unavailability of scan machine we are suffering.. Machine is not available informed by the CISF inspector.... Kindly take some action to manage this issue https://t.co/rF43zormjw
#
# 185) @kehkelungafirse @sandeep_5555 @OfficialDMRC @rishibofficial LPG 1000, petrol diesel 100s, gst collections at all time high, can't they change country with all these?
#
# 186) @OfficialDMRC a very normal day for people walking in queue to enter metro #noidasector16. https://t.co/t7i9qD5qw9
#
# 187) @OfficialDMRC someone vomit in pink line metro. Kindly have someone to clean it. https://t.co/yNCfHBuFFc
#
# 188) @OfficialDMRC The escalator from platform to ground floor at Vishwavidyalaya metro station is not working since last more than 6 days. Also it works only 2 days in a week.
# Kindly look into it. https://t.co/pyf85xhnVA
#
# 189) @OfficialDMRC If it's mandatory then why don't u take action when violation of this is reported to u?
#
# 190) RT @sandeep_5555: @OfficialDMRC @rishibofficial Washroom facilities must be free.
#
# 191) @aarnavg17 @OfficialDMRC Then they just did that intentionally to serve West Vinod Nagar as well!! Is that really highly dense area?
# And because of many turns, Pink Line average speed is quite low between Nizamuddin and Anand Vihar station.
#
# 192) @RoshanRaj08 @OfficialDMRC Not really, tbh. The roads go in other directions too, and they aren’t strictly following any.
#
# 193) @OfficialDMRC @Abhi___Abhishek Please start operation on Magenta line on Sunday as normal routine instead 8am with less frequency of train.
#
# 194) @aarnavg17 @OfficialDMRC This happened multiple times with Pink Route alignment. Instead of straight route, they took a detour.
# BTW here where they following a road underneath the elevated section?
#
# 195) @OfficialDMRC @rishibofficial Washroom facilities must be free.
#
# 196) @OfficialDMRC
# Condition of Lift at Qutub Minar really pathetic. It is full of Dust and spider webs inside the Lift cabinets... https://t.co/OOwwTC1o5s
#
# 197) Narrating an ordeal of discomfort and dishonesty: Got scammed today at Vinobhapuri metro station. I had only just arrived at the station when a young man of around 20 advanced towards me requesting money.
# @OfficialDMRC
#
# 198) @OfficialDMRC Thanks for your reply. But hardly i could see any security on platform. What about the maintenance. Handrails are filled with pigeon droppings. Can't touch. This i noticed in Jhandewalan metro station. Staircase and handrails cleaning not being done. Pl check.
#
# 199) RT @Manish_AFT: Right to equality ki band bajati hui @OfficialDMRC
#
# They talk about Old people, hypocrites they don't know that YOUNG GIRL…
#
# 200) @Critiquality_ @Manish_AFT @chit_____ @SEEMFP @OfficialDMRC You said Modi didn’t do anything but I showed you stats, poverty se leke logistic tak. He did good, but you are not accepting it. You are pointing what he missed. Similarly If someone doing it for Kejru, why can’t you accept it. see it goes both ways. 😂
#
# 201) @OfficialDMRC @subrataNE No DMRC never taken action against them.
#
# 202) @Critiquality_ @chit_____ @Bharat06200468 @SEEMFP @OfficialDMRC 🤣🤣
#
# Let the people read this convo and enjoy.
#
# Let them decide the reality. 😂🙏
#
# 203) I had paid 250 rupees through G-pay for the new metro card on 5 June 2022 at Shankar Vihar. Transaction was successful but the staff told me he didn't receive any message. So I was told it would be refunded soon. It's been 8 days but not credited to my account yet. @OfficialDMRC https://t.co/oVDnNi40SR
#
# 204) @DocStrange604 @Abhi___Abhishek @OfficialDMRC @DMRC Exactly.they r big dissuance to those law abiders who wear the mask.we r being made fun off.@OfficialDMRC  just doesn't cares
#
# 205) @Manish_AFT @chit_____ @Bharat06200468 @SEEMFP @OfficialDMRC Yes registration authority is to register your property. They have no jurisdiction to demolish your property. Right to property is still a legal right. You can't destroy someone's property and laugh on it. That is inhuman. I know bhakts will always defend their Modi papa.
#
# 206) @drsandeepsunny @OfficialDMRC Yes, its true.
# But think about the content.
#
# 207) @arjunbothra @Helen17402260 @OfficialDMRC Yes, you are true because I am a student of CA.
#
# 208) @AkashYadav97600 @OfficialDMRC Yes true. But not by closing the tickets window at evening @7pm. Also I hope you know the people travel in evening as per Metro record
#
# 209) @arjunbothra @yogeshr15986449 @OfficialDMRC +above
# If he is suffering form any kind of ill then you have to sit at home as per government statement.
#
# 210) @MohdRus320 @CPCB_OFFICIAL @OfficialDMRC @LtGovDelhi @OfficialDMRC Kindly take necessary action and upload ATR.
#
# 211) @Manish_AFT @chit_____ @Bharat06200468 @SEEMFP @OfficialDMRC You guys are so full of hatred and frustration.. who decides the houses are illegal? You can't decide, it's the courts. You cannot raze a property without a court's order... You will justify anything for Modi.. 😂
#
# 212) @OfficialDMRC have a look i recharged my card via paytm on 23 May but that time i couldn't top up due to some urgency but today i tried to top up on Avm machine but that shows me you don't have fund to top up. What's happening ? Where my money goes 🙄 https://t.co/9IkwBGgowg
#
# 213) @OfficialDMRC What Is This Happening?
# Less Masks, Full Metro No Proper Metro Time To Time
# Hence Gets Boarded In Single Train.
# Kb Control Hoga Bhasad?
# Voilet Line https://t.co/d8QDx5NZpT
#
# 214) @Critiquality_ @Manish_AFT @chit_____ @SEEMFP @OfficialDMRC 😂😂
#
# Yes that happens. But it still better than other countries for example Canada. Who can’t even let truckers protest while in India farmers blocked road for more than a year. 😂😂
#
# Difference …
#
# 215) @Bharat06200468 @chit_____ @Critiquality_ @SEEMFP @OfficialDMRC Haters will not talk about statistics bro.
#
# They mostly believe in getting services for FREE FREE FREE !!!
#
# And praise the LORD who gives everything for FREE FREE FREE !!!
#
# 216) @chit_____ @Manish_AFT @Critiquality_ @SEEMFP @OfficialDMRC Well some more stats. Keeping the size of population of India in mind and population growth rate. The data seems to do fine. Well as I said previously people will point out only negative. But we do for everyone. Difference … 😂😂 https://t.co/9gIO11m4Lj
#
# 217) @chit_____ @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Very true.
#
# People became more vocal and aware about their necessities and requirements, they got freedom to question authorities in a right way and for betterment.
#
# They are so FREE that abuse PM or President or other respected POSTS, which is impossible in other countries.
#
# 218) @Manish_AFT @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Indians Living Standards very much improved after 2014
#
# Though We have to improve More
#
# Even a Kid knows Indians Clothing etc much better in Present comparison to Early 2000s
#
# 219) @Critiquality_ @chit_____ @Bharat06200468 @SEEMFP @OfficialDMRC Compare the unemployment rate of India in 2013 to 2021 considering the population growth rate in India 2013 to 2021.
#
# If you have good analysis skills you will come to know how is it happening. And if it is just a propaganda to defame someone.
#
# 220) @OfficialDMRC Hi,
# Wanted to ask what is the procedure for addressing this issue. The operators can see it on CCTV that people aren't wearing masks yet no warnings or fines are being issued. Delhi is running at a 4.35% positivity rate.
#
# 221) @OfficialDMRC @Abhi___Abhishek U don't take any action at all
#
# 222) @OfficialDMRC  What is the issue with Yellow line, daily it's taking so much time between Chattarpur metro station to Saket Metro?
#
# 223) @OfficialDMRC Thanks for your smooth functioning DMRC. Reached Timely &amp; safely. We always love You ❣️. https://t.co/ggqq0zIamO
#
# 224) @OfficialDMRC Dear sir,
# Look at this, how much trouble people have in this cycle, get it fixed pls...#plssavetime https://t.co/CyRnIEWDmR
#
# 225) @OfficialDMRC I kindly request authorities to resume air conditioner at Netaji Subhash Place Metro Station - Pink Line Platform 4. Waiting time is around 10 min in the morning and it is underground.
#
# 226) RT @Manish_AFT: Right to equality ki band bajati hui @OfficialDMRC
#
# They talk about Old people, hypocrites they don't know that YOUNG GIRL…
#
# 227) @Critiquality_ @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC Stop treating women as a vote bank. Stop giving them everything for free when men also pay taxes. Unnecessary financial burden of every thing on men in this Indian society is the cause of increased suicides by Men. #GenderBiasedLaws will plague this nation.
#
# 228) RT @Manish_AFT: Right to equality ki band bajati hui @OfficialDMRC
#
# They talk about Old people, hypocrites they don't know that YOUNG GIRL…
#
# 229) @OfficialDMRC There is no train on my right
#
# 230) @chit_____ @Bharat06200468 @Manish_AFT @SEEMFP @OfficialDMRC What exactly is Modi praised for when he made no improvements.
#
# 231) @goelgauravbjp @HardeepSPuri @AshwiniVaishnaw @CPDelhi @DCP_DelhiMetro @OfficialDMRC what's going on?? Why no action taken yet?? As a women n daily traveler of metro how we suppose to feel safe in this kind of working environment?
#
# 232) @DeepikaBhardwaj @Uppolice @RailwaySeva, @Uppolice @cmohry @OfficialDMRC in that order. Most active and quick action.
#
# 233) RT @RAHULDutt0710: @OfficialDMRC @HardeepSPuri @LtGovDelhi
# See the disaster at kirti nagar metro station. Surface is new dustbin https://t…
#
# 234) RT @prateekrdelhi: @HardeepSPuri @OfficialDMRC Kindly approve and start work in Rithala to Narela Metro . It's already been delayed a lot .…
#
# 235) This is how parking lot of Kaushambi Metro look like. Full of garbage every day @OfficialDMRC https://t.co/1j6vdNjI7D
#
# 236) @OfficialDMRC I have complained so many times about people not wearing mask but u people r in sound sleep to attend this. Only paying formalities to ask public to use mask but in ground level no attention If someone is getting into ur attention. Keep sleeping!!!!
#
# 237) @OfficialDMRC Right side metro is missing
#
# 238) @RameshC66068551 @MCD_Delhi @LtGovDelhi @AshwaniKumar_92 @GyaneshBharti1 @DPCC_pollution @DelhiPwd @OfficialDMRC Kindly take necessary action and upload ATR.
#
# 239) RT @OfficialDMRC: Normal services have resumed.
#
# 240) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Look who was talking about KEJRI &amp;who claimed to be a DELHI RESIDENT.
#
# https://t.co/RlERdgk3Fr
#
# 😂🤣
# The same person defending KEJRI by speaking against MODI. Whereas my first tweet said
#
# https://t.co/1LLwCVz68k
#
# 241) #dmrc @OfficialDMRC @OfficialDMRC Dear DMRC,I will  work from office tomorrow. So, I hope Metro Service of Blue line is upto mark right now. Kindly update me, So I can plan my travelling time/hrs. According to the that only. #dmrc
#
# 242) @OfficialDMRC Metro on right side in not visible in 2nd pic
#
# 243) @Tanishq26309767 @OfficialDMRC Are bhai bht saare boards aise bh hain jism LED lighting ka function nh h, mtlb k vh sirf TEXT DISPLAY BOARD HAIN WITHOUT ELECTRONICS
# Vaisa ho skta h yh
#
# 244) @OfficialDMRC sec 18 metro station platform no.2 par kuch logo nay pani ki bottles or kuch rappers aasay he daalay hua ha ..plz try to clean platform....and try to find out which guys do this? https://t.co/l5kEbhXrsS
#
# 245) I have an arrival today late night at New Delhi via Railways. Kindly tell me timing of last metro from New Delhi towards Samaypur Badali
# @OfficialDMRC
#
# 246) @OfficialDMRC Dear @OfficialDMRC I request you if it possible so please start provide the facility if anyone lost their metro card so balance carry forward from old card to new metro card
#
# 247) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 248) @OfficialDMRC The one who cuts the pink line ticket in dhaula Kaun,he is very rude,he cuts the token without asking,I want to go to the civil lines,he gave the pink line token without asking me &amp; later for inquiry he started misbehaving with me &amp; said go away else fine ₹500😡😡
#
# 249) @OfficialDMRC Thanks for your reply and prompt action 🙏
#
# 250) @DrishtiSashakt @OfficialDMRC @ArvindKejriwal @DCP_DelhiMetro @smritiirani @AmitShah @HMOIndia @unwomenindia @UN @UNinIndia @PMOIndia @DeshKeMentor It was a great event. Very important and informative
#
# 251) RT @pyaraladkatha: @GajarajKalburgi @RailMinIndia @OfficialDMRC please take action
#
# 252) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC To know how much you know about working of government.
#
# 253) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Why are you dragging here?
#
# Can't you defend your beloved Kejri without dragging Modi?
#
# In the very first tweet I mentioned, it's these politicians who are doing appeasement. I never took any name.
#
# How can you say that I am in favor of Modi?
#
# 254) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC As far as I know, Indian govt charges taxes even from beggars. In some countries, govts gives tax rebates and subsidies to homeless beggars. For example US..so the tax can be zeroed.
#
# 255) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC Ok tell me on what basis you ask that tax related question? How do you know that not everyone pays taxes? Where does this knowledge come from?
#
# 256) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC I knew out of thousands of positives, you will pick one negative and pass your judgement. He is doing better though..than both of us..what would you call Modi's silence on this Hindu Muslim situation right now? Is it now biased... Oh of course you won't even see it.
#
# 257) @OfficialDMRC Actually u need new photo editor your current editor ruined the right side
#
# 258) Today right know  i am traveling delhi metro and i see  women reserved coache there are some  male IN sitting metro staff not check by this is women safty next station is janpath to words rajanhar singh metro station @OfficialDMRC
#
# 259) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC A biased LEADER can never become a TRUE or BEST LEADER.
#
# His biasness will STOP him making good decision, justice and good non biased governance.
#
# 260) @OfficialDMRC The concessional fare on Sundays &amp; holidays is v good EXTRA money making thing for your token window operators.
# Most of the times they cheat public with deducting FULL FARE and handing over CONCESSIONAL value token on these Sundays/holidays
# Pls check this LOOP HOLE!
#
# 261) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Who said Modi is a good choice?
# https://t.co/BXynM6PItn
# I just saw your love for Kejri keep loving him it's your choice.
#
# I said already that I am not into politics, but that doesn't mean I don't know how govt works. Stop judging people jus coz u in Delhi
#
# https://t.co/d9nGBZGBzZ
#
# 262) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC I think I have answered your third question in answer for second. But I know you guys are hellbent and still find this or that thing to criticise.. you are free.. but that doesn't help for the nation. Modi is not a good choice, Kejri is..he is educated and has good intentions.
#
# 263) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC Your second question, It is not Delhi population, they r Indian citizens paying GST and Direct taxes. 50% of GST goes to Delhi and 41% of Central direct taxes (TDS). If Delhi govt wants to spend these proceeds on freebies, they can..while keep the govt in surplus (CAG data)
#
# 264) @OfficialDMRC  Please clean D7F029 on Pink line asap. People are not able to sit there due to hygiene issues.
#
# 265) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC First of all understand what is tax..in India, even a baby pays tax for pooping in a diaper, a non earning adolescent girl pays tax for her sanitary napkins... Yes, you can say their fathers pay those taxes.. but those are not direct taxes. Direct tax is charged over and extra.
#
# 266) RT @Manish_AFT: @Bharat06200468 @SEEMFP @OfficialDMRC Condutor literally said these words - "FREE ke chakkar me logo ko nikamma bana de rah…
#
# 267) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Yes bro, you know everything.
# You are great. You are in DELHI and so you know how government works.
# You are in Delhi so you know everything about politics.
# You are in Delhi hence you are the KING &amp; what you said is 💯% correct others are not.
#
# 268) @Critiquality_ @Bharat06200468 @SEEMFP @OfficialDMRC Are all 100% of the people utilising free facility paying tax??
# Are the free facilities provided only coz of tax paid by DELHI population Or they are taking funds from central government?
# Whose money they are utilising in DELHI to provide facility when they ask central for funds?
#
# 269) RT @amanshrmax: @OfficialDMRC
#
# The Skywalk between Dhaula Kaun and Durgabai Deshmukh is dirty, shabby and not clean. It feels like it has…
#
# 270) RT @Narende79190562: Can't allow this kind of people in public domain @OfficialDMRC please take action
#
# 271) @OfficialDMRC 13:25/12th June 2022/ Shastri Nagar metro station . Broad daylight. Outside corridor. Lights on https://t.co/978qfmK6L7
#
# 272) @dtptraffic @Opchaudhary07 @PTI_News @PMOIndia @ArvindKejriwal @OfficialDMRC @DCPSouthDelhi @nitin_gadkari @kgahlot @RoadSafetyWA @pwddelhi @LtGovDelhi No action till today
#
# 273) I don't think @OfficialDMRC has specified a particular kind of mask that people must use. If so, please let me know. @OfficialDMRC @AAPDelhi @ArvindKejriwal Request you to kindly look into the matter. #DelhiMetro
#
# 274) Was stopped from entering a metro station by a @OfficialDMRC staff for wearing a creative mask. Moreover, the way he behaved was awful. No freedom of expression, it seems! Have been wearing such masks for a while now but this is the first time such an incident has happened. https://t.co/T0XFCeVuPR
#
# 275) @OfficialDMRC
#
# The Skywalk between Dhaula Kaun and Durgabai Deshmukh is dirty, shabby and not clean. It feels like it has been weeks that It was cleaned last time. Can you check as Delhi Metro is not like this! https://t.co/LIajZcJ8Jy
#
# 276) RT @pyaraladkatha: @GajarajKalburgi @RailMinIndia @OfficialDMRC please take action
#
# 277) RT @Narende79190562: Can't allow this kind of people in public domain @OfficialDMRC please take action
#
# 278) Can't allow this kind of people in public domain @OfficialDMRC please take action https://t.co/Efpmyr4xCL
#
# 279) @OfficialDMRC what the hell is happening with u guys.. Will i get the solution or not.. Firstly give the coaching to your entire uttam nagar east team. They don't know how to speak with the people,, they think we ara uneducated and gawar. They always treat like that way. Start r
#
# 280) @OfficialDMRC Means they are charging this fine illegally!! https://t.co/w1B0lzmYwk
#
# 281) @Critiquality_ @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC Taking tax form Men and free service to Female..I am doubting on Kezri qualification...and mental status...
#
# 282) @OfficialDMRC @HardeepSPuri @LtGovDelhi
# See the disaster at kirti nagar metro station. Surface is new dustbin https://t.co/WNOr7lJnTo
#
# 283) RT @pyaraladkatha: @GajarajKalburgi @RailMinIndia @OfficialDMRC please take action
#
# 284) @goelgauravbjp @HardeepSPuri @AshwiniVaishnaw @CPDelhi @DCP_DelhiMetro Why shameless @OfficialDMRC has not initiated action till now ????
#
# 285) @Manish_AFT @Bharat06200468 @SEEMFP @OfficialDMRC There r millions of people like that conducter and possibly you who don't know how governments work. Govt is meant for people's welfare. They r not giving you anything for free rather, they are using your surplus tax money to give you perks like these. And everyone pays tax here.
#
# 286) @kinglia79911461 @OfficialDMRC It's  100% Right but there is CCTV surveillance for those nalayak person need to fine them with huge amount while no drinking and eating tc.. there ....by #DMRC
#
# 287) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 288) @OfficialDMRC No train on the rail on the right in one picture
#
# 289) @OfficialDMRC There is no metro on the right
#
# 290) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 291) Hello @OfficialDMRC
# Is this legal to put a billboard on Metro Red line towards airport and that too with this much lights?
#
#  If this is legal, i would like to know more about it!!! https://t.co/eAG5VFhnMR
#
# 292) Every time @OfficialDMRC faces any technical issue and this hapens only in the peak hour's..... So why you charge the same amount as in normal service and pathetic service..If you are not giving the service on time you should be penalized for it same as companies does ...
# 1/2
#
# 293) @OfficialDMRC Three metro trains in first pic but only two in 2nd
#
# 294) @GajarajKalburgi @RailMinIndia @OfficialDMRC please take action
#
# 295) @OfficialDMRC I have recharged my Metro Card. Recharge is success but balance is not reflecting In my card when I say Assistant than tell me Balance is refund your account with deduct balance 2.5% of recharge value. why you deduct 2.5% value. This is your fault but not mine. https://t.co/RzXvQucy9E
#
# 296) @OfficialDMRC I have recharged my Metro Card. Recharge is success but balance is not reflecting In my card when I say Assistant than tell me Balance is refund your account with deduct balance 2.5% of recharge value. why you deduct 2.5% value. This is your fault but not mine.
#
# 297) @OfficialDMRC
# Train towards to huda City centre
# Currently cross chandhni chowk
# Last coach of metro pls clean this https://t.co/CaJb3Q6r0i
#
# 298) @OfficialDMRC This is not a New case.there are resistance always stuck on metro line and DMRC have very expensive  fair and in the name of facility it is zero
#
# 299) RT @millindtripathi: So much crowd and chaos in the metro.
# The sudden braking makes people fall over each other. *Inconvenience*
# @OfficialD…
#
# 300) @OfficialDMRC Good question....Keep it up....
#
# 301) @OfficialDMRC No train on the extreme right track.
#
# 302) @OfficialDMRC
# #Airportexpressline
# Can u pls see the services which you are giving to us ...... with the highest fare.... without and cleaning  protocols...??? https://t.co/8qNY6yVNrp
#
# 303) @OfficialDMRC @OfficialDMRC Respected Sir ..could you please start Red line Metro little early like u did on upsc paper day as tomorrow uppcs paper is scheduled and Lots of candidates are having centre in Ghaziabad Thanks in Advance Sir 🙏🙏
#
# 304) @OfficialDMRC Respected Sir ..A very Humble Request , Could you please start Red line Metro little early by 6:00 AM..like u did on UPSC paper day. As tomorrow "UPPCS" PRELIMS paper is scheduled and Lots of candidates are having centre in Ghaziabad..Thanks in Advance Sir 🙏🙏 https://t.co/e0cgoyyszj
#
# 305) @CPCB_OFFICIAL @nisharai_ggc @fortis_hospital @CeoNoida @CP_Noida @dmgbnagar @rouppcbgbn @byadavbjp @112UttarPradesh @noidatraffic @noida_authority @jeetsanwar @emishrajee @DineshSAmethi @CMOfficeUP @Uppolice @dgpup @ShishirGoUP @rouppcbgbn Please update the latest status and upload action taken report on the aforementioned complaint. Furthermore, upload the latest #Noise level measurements at @fortis_hospital T junction and at @OfficialDMRC metro station platforms at Sector 62 and 61. @Secretary_MoHUA https://t.co/oMCK7tAvE6
#
# 306) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 307) In Nirman Vihar metro station, why there has been no escalator provided on V3s mall side so far, although space is there. It is main stop for office goers in scope minar next to it and they face so much trouble as I'm facing this since last 4 years. Pl arrange @OfficialDMRC
#
# 308) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 309) RT @OfficialDMRC: Normal services have resumed.
#
# 310) @OfficialDMRC Exit from new delhi metro station has no escalator at the gate nearest to railway station/platforms. It's really tough to exit with luggage. Most people exiting from this metro station carry heavy luggage  for obvious reasons. Kindly do the needful. Thanks.
#
# 311) Everyone standing at beyond yellow line at jahangir puri meteo station,  specially man carrying a small baby  with him and taking risk @OfficialDMRC @jahangirpuri @Delhinetro https://t.co/SbgKX2qVFs
#
# 312) What is the starting timings for Delhi metro on Sundays particularly on #BlueLine #GreyLine and #AirportExpress line ? @OfficialDMRC
#
# 313) @OfficialDMRC What do I win?
#
# 314) @OfficialDMRC Filming inside Metro and Metro Premises is a punishable offence and violates my privacy. You should take action on yourself.
#
# 315) @DrishtiSashakt @OfficialDMRC @ArvindKejriwal @DCP_DelhiMetro @smritiirani @AmitShah @HMOIndia @unwomenindia @UN @UNinIndia @PMOIndia @DeshKeMentor My experience with delhi metro has been amazing. Though there is something that i didn't like and  it's that I've seen men sitting in women's coach. I would appreciate if the authorities take an action regarding this.
# #ChaleStreeStressFree
#
# 316) @OfficialDMRC right most metro is not therr
#
# 317) @Bhawna_s029 @OfficialDMRC Warm greetings from @CISFHQrs. Thank you for taking time and sharing your valuable feedback acknowledging good works done by CISF personnel. Wish you a wonderful day
#
# 318) @OfficialDMRC @ArvindKejriwal
# Kashmiri gate metro station gate no -4 there are so many dart and there are not clean https://t.co/gCk8N6jzBt
#
# 319) @OfficialDMRC @GaganMakkar9821 Close all the shop inside metro station. People taking lightly Delhi Metro announcement regarding eating and drinking not allowed.
#
# 320) @OfficialDMRC Nothing new every second day we are facing a problem someday on this route someday on blue line.
#
# 321) @OfficialDMRC Right side 6 coach metro is missing in down picture.
#
# 322) @RoshanRaj08 @OfficialDMRC Trains are quite small, feel congested. I was underground, and lighting felt horrible in comparison to other underground trains.
#
# 323) @OfficialDMRC the car on the right ! where's my chocolate.
#
# 324) @aarnavg17 @OfficialDMRC Yeah Violet Line also has all the above pros plus ambience feels more modern. Only trains are little smaller and frequency is always more than 3-4 mins.
#
# 325) @RoshanRaj08 @OfficialDMRC Honestly, I don’t mind the Red line. It does feel a bit old, but it is really reliable, speed is good too. And since it is entirely above ground, I guess, lighting remains better.
#
# 326) @OfficialDMRC Hi can you confirm me timing of first train Sunday Red line metro
#
# 327) @OfficialDMRC Dmrc increased the coaches to 8 in the train for public convenience. It's a good effort.
# This is the difference.
#
# 328) @OfficialDMRC Only one of the metro trains is of 06 coaches in yellow🟡 line now. Remaining all are of 08 coaches.Train having 04 coaches only is not being seen.
# Am I right?
#
# 329) @aarnavg17 @OfficialDMRC Yeah it does feel new, may be because of being underground but also trains, signalling and frequency is much much better. Also serves the heart of Indian Government, may be that has something to do with it.
#
# 330) @OfficialDMRC Metro on the bottom right is missing as it is stuck at Yamuna bank as usual.
#
# 331) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 332) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 333) @OfficialDMRC only middle train light is on
#
# 334) RT @CISFHQrs: @goyalsach9911 @OfficialDMRC Warm greetings from @CISFHQrs Thank you for taking time and sharing your valuable feedback ackno…
#
# 335) @RoshanRaj08 @OfficialDMRC I really don’t know why Yellow line, despite being as old as Red and Blue, feels much much much newer in comparison. The platforms, the trains, the service. It not having a branch helps, and maybe it’s a lot more underground, that’s why. Dunno.
#
# 336) @OfficialDMRC DMRC ke passenger dekho @officialDMRC difference-difference khel rahi hai isliye metro ki efficient functioning ho Rahi hai. And you are always getting tweets from DMRC from a week that "There is delay in blue and normal functioning in other lines" like this DMRC are playing.
#
# 337) @OfficialDMRC It's not like that DMRC is not capable to perform above duties, Yellow Line continues to be island of calmness among all the recent chaos. So it's upto DMRC to improve management of troubled corridors. We wish DMRC well for this but remain sceptic and will wait for the results.
#
# 338) RT @OfficialDMRC: Voilet Line update
#
# Delay in services between Kashmere Gate and Raja Nahar Singh (Ballabgarh).
#
# Normal services on all…
#
# 339) @OfficialDMRC Public trust which is very difficult to garner has gone down for the Metro.
# When DMRC is already suffering from financial restraints due to Covid and struggling to regain its lost ridership, can't afford this. It has to refocus its personnel for providing best commuter experience
#
# 340) @OfficialDMRC Right side metro not available in 2nd pic.
#
# ...
#
# 694) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 695) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 696) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 697) As usual, even today the blue line metro is late.  It doesn't matter.  you will not be ashamed @OfficialDMRC
#
# 698) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 699) @OfficialDMRC It seems metros are delayed  at green line intentionally..
#
# 700) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 701) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 702) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 703) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 704) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 705) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 706) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 707) @yogeshr15986449 @DivasKu05656899 @OfficialDMRC Yup, he could be suffering from ill or maybe sole earner of his family or it could be anything. Since there is no harm then what's wrong? As if he didn't sleep in school or work or even feeling like to take a nap?
#
# 708) @aarnavg17 @OfficialDMRC No water facility in summers in metro station, pink line train speed is too too too slow
#
# 709) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 710) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 711) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 712) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 713) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 714) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 715) @OfficialDMRC , as a daily commuter, I wnt to knw if i m spending 4-5hrs of my day travelling in metro, is it really an offence that I eat while I am hungry n I am well aware that I have 1-2 hr long journey left? Becz this is the announcement that you make - eating... Prohibited
#
# 716) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 717) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 718) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 719) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 720) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 721) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 722) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 723) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 724) @OfficialDMRC Sir/Ma'am
# Pink line metro has been constantly running late for the past couple of days. Can you please clarify the reason?
#
# 725) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 726) RT @OfficialDMRC: Delhi Metro has made minor changes in its last train timings to facilitate the spectators during T-20 Cricket match betwe…
#
# 727) #DMRC
# Why don't you bid for our hidden heroes...the retired or expert Sniffer dogs to your team across all the inputs
#
# 728) Delhi Metro Update: Tender invited for various work including modification of viaduct and stations from Samaypur badli to Azadpur metro stations line-2
#
# Read more...https://t.co/uxpeWMsdOp
#
# @OfficialDMRC
#
# #DMRC #metro #infrastructure #stations #delhimetro #tender #metroline2 https://t.co/mBJV1Y6KhQ
#
# 729) RT @Therealtalkin: There has been damage to the overhead electrification wire due to a flash over by an external object between Yamuna Bank…
#
# 730) @CPDelhi #DMRC construction on GT Karnal Road Worst traffic management. Today a big open cargo truck parked in middle of road which is already reduced to 1/3rd by scrupulous contractors is creating havoc on the road , please intervene @CPCB_OFFICIAL @dtptraffic @HardeepSPuri
#
# 731) Pink line timing #dmrc??
#
# 732) Taking action in the interest of commuters to ensure their hassle-free movement, #DMRC is planning to carry Multimodal Integration at East Delhi's Shahdara Metro Station. In an eco-friendly move, the station's spacious parking got a green makeover. https://t.co/o2ss56P2pe
#
# 733) NMRC reviews plan for Noida Sec 142-Botanical Garden metro stretch #BotanicalGarden #BotanicalGardenMetro #Nmrc #Noida #Dmrc #DelhiMetroRailCorporation #NoidaExtension #NoidaMetroRailCorporation #Wadhwa #AquaLine  https://t.co/b3JXKTJfHd
#
# 734) RT @ZeeNewsEnglish: #DelhiMetro: Violet line services delayed due to technical snag, commuters suffer
#
# #DMRC  #Metro
#
# https://t.co/DQc8F…
#
# 735) #DelhiMetro: Violet line services delayed due to technical snag, commuters suffer
#
# #DMRC  #Metro
#
# https://t.co/DQc8F28FXt
#
# 736) Delhi has new services in line
# "Delayed Metro Rail Corporation"#DMRC
#
# No more lame excuses of getting late. Just say,the all new @OfficialDMRC #DMRC #VioletLine #DelayedMetroRailCorporation
# @CMODelhi @TransportDelhi @AAPDelhi
#
# 737) @OfficialDMRC
# #DMRC #violetline #bluelie What's going on ? Again another line (violet) on stuck.. 1 hours to cover hardly 3 station.
#
# 738) RT @pallabghosh: Ruckus at Sec 15 Noida Metro Station. All confused. Some saying suicide, others fire at Yamuna Bank. Passengers harassed.…
#
# 739) #DelhiMetro commuters, largely office-goers, on Thursday faced hardship, as services on its #BlueLine were delayed for over two hours due to a technical snag.
#
# #DMRC
#
# https://t.co/NMTc66iqKU
#
# 740) #Train services between #YamunaBank and #Indraprastha station of the #BlueLine were affected from 06:43 am  to 9:45 am today to undertake the repair work of a broken catenary wire on the UP Line which goes towards #Dwarka: #DMRC
#
# 741) RT @bsindia: Disrupting travel thrice in the past four days, train services on Delhi Metro's blue line were delayed yet again after damage…
#
# 742) [Delhi Metro Update]
#
# Delay in Delhi Metro services yet again due to technical snag
# Read here: https://t.co/O5gCpBuS5H
#
# #BlueLine #delay #DelhiMetro #DMRC #services #Technicalsnag #office #late #MetroRailNews
#
# 743) RT @bsindia: Disrupting travel thrice in the past four days, train services on Delhi Metro's blue line were delayed yet again after damage…
#
# 744) RT @bsindia: Disrupting travel thrice in the past four days, train services on Delhi Metro's blue line were delayed yet again after damage…
#
# 745) Disrupting travel thrice in the past four days, train services on Delhi Metro's blue line were delayed yet again after damage to the Over Head Electrification wire.
#
# #DelhiMetro #DMRC
# https://t.co/p8ut4aJN8W
#
# 746) @OfficialDMRC #DMRC is getting worse day by day especially in the blue line, very pathetic service for its passengers. Every day it's running 20,25 minutes late whenever I choose to travel by metro in the blue line. #Shameful #DMRC
#
# 747) Closing of metro gates for dignitary travel during peak office hours is cruel! #dignitarytravel #closingmetrogates #DMRC https://t.co/o3TZyxHCFd
#
# 748) Delhi Metro faces delay in services between Dwarka Sector 21 and Noida Electronic City/Vaishali due to technical snag. Use different medium to travel.
#
# #DelhiMetro #DMRC #delhimetrodelay
#
# 749) Delhi Metro faces delay in services between Dwarka Sector 21 and Noida Electronic City/Vaishali due to technical snag
#
# #DelhiMetro #DMRC #delhimetrodelay
#
# 750) There has been damage to the overhead electrification wire due to a flash over by an external object between Yamuna Bank and Indraprastha. Repair work is being done: #DMRC
#
# #TheRealTalkin (ANI) https://t.co/RfPvJgve0W
#
# 751) DMRC Fucked up today 🥲.
# DMRC kindly take a look on the problems that are going on for this delay.. Consider soon many us are late for our work locations..
# #DMRC #arvindkejriwal #delhimetro
# @OfficialDMRC @ArvindKejriwal https://t.co/KWX32mxa0O
#
# 752) Impeccable service of @OfficialDMRC
# Commuters can just not reach on time, be it in the morning or evening. They should get late to work and late to homes. Amazing!
# #DMRC #poorservicedmrc https://t.co/5RFIgf5kSN
#
# 753) RT @indiatvnews: Delhi Metro services disrupted on #BlueLine due to technical issues
#
# #delhimetro #DMRC #Metro
#
# https://t.co/eamVEYCZk9
#
# 754) Delhi Metro services disrupted on #BlueLine due to technical issues
#
# #delhimetro #DMRC #Metro
#
# https://t.co/eamVEYCZk9
#
# 755) Delhi Metro: Blue Line Metro malfunctions again, many metros running late, DMRC tweeted
#
# #DMRC #DelhiMetro https://t.co/4K6CeaN2NM
#
# 756) Isn't it's the responsibility of @OfficialDMRC to maintain there networks?
# Bcs the service quality is becoming worst every 2nd day!!!
# That too when #DMRC recordes 30Lakh+  'passenger trips' on average daily!
# I am saying so coz I'm suffering!!!
# #Metro #DMRC #blueline #DMRC https://t.co/k4btDNgocv
#
# 757) #metro please avoid blue line for next couple of hours.#DMRC why can't you announce at stations don't you know people are suffering because of your poor information system!!!
#
# 758) [Delhi Metro Update]
#
# Delhi Metro announces minor changes in timings for India-South Africa T-20 spectators
# Read here: https://t.co/BER1p1hhSk
#
# #changes #Cricket #DelhiMetro #DMRC #SouthAfrica #T20 #Timings #India #MetroRailNews
#
# 759) RT @rohityadav1098: DMRC changes the timing of the last train by +30-40 mins due to #INDvSA
#
# The last train on Yellow Line from Huda City…
#
# ***********************************************************
# ***********************************************************
# *** 	1 .....Show Tweets                            ****
# *** 	2 .....Show graphs                            ****
# *** 	3 .....Model creation                         ****
# *** 	4 .....Topic Modelling                        ****
# *** 	5 .....Tweets sentiments using model created  ****
# *** 	6 ..... Exit                                  ****
# ***********************************************************
# ***********************************************************
# Enter a choice      :::: 3
# __________________________________________________
# |    1.  Multonmial Naive bayes                  |
# |    2.  SVC                                     |
# |    3.  KNN                                     |
# |    4.  RAndom forest                           |
# |    5.  Aadaboost                               |
# |    6.  show accuracy of all                    |
# |    7.  Boosting of Random forest               |
# |    8.  Boosting of Multinomial naive bayes     |
# |    9.  Exit                                    |
# |________________________________________________|
# enter a choice 4
# ____________Applying algorithms_____________
# X Test
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88       243
#            1       0.86      0.99      0.92       450
#            2       0.94      0.81      0.87       257
#
#     accuracy                           0.90       950
#    macro avg       0.92      0.87      0.89       950
# weighted avg       0.90      0.90      0.90       950
#
# X Train
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       516
#            1       1.00      1.00      1.00      1007
#            2       1.00      1.00      1.00       693
#
#     accuracy                           1.00      2216
#    macro avg       1.00      1.00      1.00      2216
# weighted avg       1.00      1.00      1.00      2216
# __________________________________________________
# |    1.  Multonmial Naive bayes                  |
# |    2.  SVC                                     |
# |    3.  KNN                                     |
# |    4.  RAndom forest                           |
# |    5.  Aadaboost                               |
# |    6.  show accuracy of all                    |
# |    7.  Boosting of Random forest               |
# |    8.  Boosting of Multinomial naive bayes     |
# |    9.  Exit                                    |
# |________________________________________________|
# enter a choice 9
# ____________Applying algorithms_____________
# ***********************************************************
# ***********************************************************
# *** 	1 .....Show Tweets                            ****
# *** 	2 .....Show graphs                            ****
# *** 	3 .....Model creation                         ****
# *** 	4 .....Topic Modelling                        ****
# *** 	5 .....Tweets sentiments using model created  ****
# *** 	6 ..... Exit                                  ****
# ***********************************************************
# ***********************************************************
# Enter a choice      :::: 5
# WARNING: !! Train the model first
# RandomForestClassifier()
# the accuracy is
# 0.8957894736842106
# ******************************************
#  Enter a stringmetro not working
# ******************************************
# *******************OUTPUT**********
# [1]
# ***********************************************************
# ***********************************************************
# *** 	1 .....Show Tweets                            ****
# *** 	2 .....Show graphs                            ****
# *** 	3 .....Model creation                         ****
# *** 	4 .....Topic Modelling                        ****
# *** 	5 .....Tweets sentiments using model created  ****
# *** 	6 ..... Exit                                  ****
# ***********************************************************
# ***********************************************************
# Enter a choice      :::: 4
# ***********************************************************
# ***********************************************************
# *** 	1 .....Show Tweets                            ****
# *** 	2 .....Show graphs                            ****
# *** 	3 .....Model creation                         ****
# *** 	4 .....Topic Modelling                        ****
# *** 	5 .....Tweets sentiments using model created  ****
# *** 	6 ..... Exit                                  ****
# ***********************************************************
# ***********************************************************
# Enter a choice      :::: 6
